# %% [markdown]
# # TA Maker - Kaggle Runner
# Autonomous execution of A1111 pipeline

# %%
# !git clone https://github.com/codesam-com/ta_maker.git

# %%
# %cd ta_maker

# %%
# !python kaggle/runner.py
